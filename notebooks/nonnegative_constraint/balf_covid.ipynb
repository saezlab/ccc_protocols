# %% [markdown]
# This tutorial will demonstrate how to pre-process single-cell raw UMI counts to generate expression matrices that can be used as input to cell-cell communication tools. We will assume appropriate quality-control (QC) has already been applied to the dataset (e.g., exclusion of low-quality cells and doublets). We recommend the tutorial by [Luecken & Theis](https://doi.org/10.15252/msb.20188746) as a starting point for a detailed overview of QC and single-cell RNAseq analysis pipelines in general.
#
# Here we will focus on:
# 1. Normalization
# 2. Batch correction (for multiple samples/contexts)
#
# We demonstrate a typical workflow using the popular single-cell analysis software [scanpy](https://scanpy.readthedocs.io/en/stable/) to generate an AnnData object which can be used downstream. Preferably, the workflow can maintain non-negative counts since Tensor-cell2cell uses a non-negative decomposition.
#
# For use with Tensor-cell2cell, we want a dataset that represents >2 contexts. We also want a dataset that contains [replicates](https://www.nature.com/articles/nmeth.3091). Replicates will allow us to ensure that the output factors are not simply due to technical effects (i.e., a factor with high loadings for just one replicate in the context dimension). We will use a [BALF COVID dataset](https://doi.org/10.1038/s41591-020-0901-9), which contains 12 samples associated with "Healthy Control", "Moderate", or "Severe" COVID contexts. This dataset does not contain technical replicates since each sample was taken from a different patient, but each sample associated with a context is a biological replicate. [Batch correction](https://www.nature.com/articles/s41592-018-0254-1) removes technical variation while preserving biological variation bewteen samples. We can reasonably assume that the biological variation in samples between contexts will be greater than that of those within contexts after using appropriate batch correction to remove technical variation. Thus, we expect Tensor-cell2cell to capture overall communication trends differing between contexts and can then assess that output factors aren't simply due to technical effects by checking that the output factors have similar loadings for biological replicates and do not have  high loadings for just one sample in the context dimension.

# %%
import os

import scanpy as sc
import pandas as pd
import numpy as np

import sys
sys.path.insert(1, '/home/hratch/Projects/CCC/ccc_protocols/scripts/')
from cell2cell_dev.datasets.load_data import CovidBalf

import warnings
warnings.filterwarnings('ignore')

seed = 888

# %% [markdown]
# The 12 samples can be downloaded as .h5 files from [here](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE145926). You can also download the cell metadata from [here](https://raw.githubusercontent.com/zhangzlab/covid_balf/master/all.cell.annotation.meta.txt)
#
# cell2cell has a helper function to download and format the raw UMI counts and metadata:

# %%
covid_balf_data = CovidBalf(data_path = '/data3/hratch/ccc_protocols/raw/covid_balf/')
# covid_balf_data.download_data()
md, balf_samples = covid_balf_data.format_data()

md.head()
# Out:
#                    Sample_ID sample_new          Context disease hasnCoV  \
# cell_barcode
# AAACCCACAGCTACAT_3      C100        HC3  Healthy_Control       N       N
# AAACCCATCCACGGGT_3      C100        HC3  Healthy_Control       N       N
# AAACCCATCCCATTCG_3      C100        HC3  Healthy_Control       N       N
# AAACGAACAAACAGGC_3      C100        HC3  Healthy_Control       N       N
# AAACGAAGTCGCACAC_3      C100        HC3  Healthy_Control       N       N
#
#                     cluster    cell_type
# cell_barcode
# AAACCCACAGCTACAT_3       27            B
# AAACCCATCCACGGGT_3       23  Macrophages
# AAACCCATCCCATTCG_3        6            T
# AAACGAACAAACAGGC_3       10  Macrophages
# AAACGAAGTCGCACAC_3       10  Macrophages

# %% [markdown]
# balf_samples is a dictionary with keys as each sample and values as an AnnData object storing the raw UMI counts for that sample

# %%
balf_samples_norm = dict()
for sample, adata in balf_samples.items():
    adata_norm = adata.copy()
    sc.pp.normalize_total(adata_norm, target_sum=1e6) # CPM normalize
    sc.pp.log1p(adata_norm) # logarithmize
    
    balf_samples_norm[sample] = adata_norm

# %%
# import scanorama

# corrected, genes = scanorama.correct_scanpy([balf_samples['C100'], balf_samples['C152']])

# %%
adata_concat = balf_samples['C100'].copy()
adata_concat = adata_concat.concatenate(balf_samples['C152'], batch_categories=['C100', 'C152'])
sc.pp.pca(adata_concat)
sc.external.pp.bbknn(adata_concat, batch_key='Sample_ID')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       2 adata_concat = adata_concat.concatenate(balf_samples['C152'], batch_categories=['C100', 'C152'])
#       3 sc.pp.pca(adata_concat)
# ----> 4 sc.external.pp.bbknn(adata_concat, batch_key='Sample_ID')
#
# File ~/anaconda3/envs/FDA_collab/lib/python3.9/site-packages/scanpy/external/pp/_bbknn.py:108, in bbknn(adata, batch_key, approx, metric, copy, n_pcs, trim, n_trees, use_faiss, set_op_mix_ratio, local_connectivity, **kwargs)
#     106 except ImportError:
#     107     raise ImportError('Please install bbknn: `pip install bbknn`.')
# --> 108 return bbknn(
#     109     adata=adata,
#     110     batch_key=batch_key,
#     111     approx=approx,
#     112     metric=metric,
#     113     copy=copy,
#     114     n_pcs=n_pcs,
#     115     trim=trim,
#     116     n_trees=n_trees,
#     117     use_faiss=use_faiss,
#     118     set_op_mix_ratio=set_op_mix_ratio,
#     119     local_connectivity=local_connectivity,
#     120     **kwargs,
#     121 )
#
# File ~/anaconda3/envs/FDA_collab/lib/python3.9/site-packages/bbknn/__init__.py:124, in bbknn(adata, batch_key, use_rep, approx, use_annoy, metric, copy, **kwargs)
#     122 batch_list = adata.obs[batch_key].values
#     123 #call BBKNN proper
# --> 124 bbknn_out = bbknn_matrix(pca=pca, batch_list=batch_list, approx=approx,
#     125 						 use_annoy=use_annoy, metric=params['metric'], **kwargs)
#     126 #store the parameters in .uns['neighbors']['params'], add use_rep and batch_key
#     127 adata.uns['neighbors'] = {}
#
# TypeError: bbknn() got an unexpected keyword argument 'n_trees'

# %%
# !pip install bbknn
# Out:
# Collecting bbknn
#   Using cached bbknn-1.5.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (21.3)
# Requirement already satisfied: annoy in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (1.17.0)
# Requirement already satisfied: umap-learn in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (0.5.2)
# Requirement already satisfied: Cython in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (0.29.28)
# Requirement already satisfied: numpy in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (1.22.3)
# Requirement already satisfied: scikit-learn in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (1.0.2)
# Requirement already satisfied: scipy in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (1.8.0)
# Requirement already satisfied: pynndescent in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from bbknn) (0.5.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from packaging->bbknn) (3.0.7)
# Requirement already satisfied: joblib>=0.11 in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from pynndescent->bbknn) (0.17.0)
# Requirement already satisfied: numba>=0.51.2 in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from pynndescent->bbknn) (0.53.1)
# Requirement already satisfied: llvmlite>=0.30 in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from pynndescent->bbknn) (0.36.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from scikit-learn->bbknn) (2.1.0)
# Requirement already satisfied: tqdm in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from umap-learn->bbknn) (4.63.0)
# Requirement already satisfied: setuptools in /home/hratch/anaconda3/envs/FDA_collab/lib/python3.9/site-packages (from numba>=0.51.2->pynndescent->bbknn) (60.10.0)
# Installing collected packages: bbknn
# Successfully installed bbknn-1.5.1

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/FDA_collab/lib/python3.9/site-packages/scanpy/external/pp/_bbknn.py:105, in bbknn(adata, batch_key, approx, metric, copy, n_pcs, trim, n_trees, use_faiss, set_op_mix_ratio, local_connectivity, **kwargs)
#     104 try:
# --> 105     from bbknn import bbknn
#     106 except ImportError:
#
# ModuleNotFoundError: No module named 'bbknn'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 adata_concat = balf_samples['C100'].copy()
#       2 adata_concat = adata_concat.concatenate(balf_samples['C152'], batch_categories=['C100', 'C152'])
# ----> 3 sc.external.pp.bbknn(adata_concat, batch_key='Sample_ID')
#
# File ~/anaconda3/envs/FDA_collab/lib/python3.9/site-packages/scanpy/external/pp/_bbknn.py:107, in bbknn(adata, batch_key, approx, metric, copy, n_pcs, trim, n_trees, use_faiss, set_op_mix_ratio, local_connectivity, **kwargs)
#     105     from bbknn import bbknn
#     106 except ImportError:
# --> 107     raise ImportError('Please install bbknn: `pip install bbknn`.')
#     108 return bbknn(
#     109     adata=adata,
#     110     batch_key=batch_key,
#    (...)
#     120     **kwargs,
#     121 )
#
# ImportError: Please install bbknn: `pip install bbknn`.

# %%
balf_samples['C100'], balf_samples['C152']

# %% [markdown]
# # Batch correction:
#
# # you are here

# %% [markdown]
# Finally, we apply a batch correction. The goal here is to account for sample-to-sample technical variability. In this case, we show Combat since it is built in with scanpy.
#
# Note, the final input matrices to Tensor-cell2cell must be non-negative. We will demonstrate workarounds to negative counts in the tensor building tutorial.
#
# See 10.1186/s13619-020-00041-9 for a benchmarking of Scanpy's batch correction methods

# %%
batch_var = 'Sample_ID' # the batch variable in the metadata

# %% [markdown]
# Batch correction using combat:

# %%
# merge the balf_samples
balf_corrected = sc.concat(balf_samples.values())
balf_corrected.obs_names_make_unique()

# store log(1+CPM) values in "raw" attribute
balf_corrected.raw = balf_corrected 

# do the batch correction
sc.pp.combat(balf_corrected, key = batch_var)

# %% [markdown]
# At some point in the pipeline, we must account for batch. Batch-correction is important since Tensor-cell2cell considers multiple balf_samples to extract context-dependent patterns, and we want to make sure we are capturing true biological signals rather than sample-specific differences due to technical variability.
#
# Ideally, we can use single-cell RNAseq batch correction methods. There are a few potential problems with this approach:
#
# 1) Batch correction methods often return a matrix in a reduced space and thus does not have the original gene features included, which is needed for LR scoring (see [Table 1](https://academic.oup.com/nargab/article/4/1/lqac022/6548822)).
#
# 2) Some cell-cell communication tools expect data in other formats, such as log(1+CPM)
#
# 3) Batch correction methods that do return gene counts often return negative counts which can result in negative LR scores. Negative values in the tensor can bias non-negative TCD, the main algorithm used in Tensor-cell2cell.
#
# In this tutorial, and its companion 01B for R users, we will show pre-processing from raw counts to batch corrected counts. Problem 1 can simply be dealt with by only using batch correction methods that return the original gene features. Problem 2-3 will be discussed further in Tutorials XXX. Essentially, Problems 2-3 can both be dealth with by instead directly introducing a technical covariate to account for batch directly to the decomposition. Problem 3 can also be dealt with either by masking negative values or using a TCD approach that does not have a non-negative constraint.

# %% [markdown]
# The next two cells, unused, show examples of other methods for batch correction . See https://nbisweden.github.io/workshop-scRNAseq/labs/compiled/scanpy/scanpy_03_integration.html for more tutorials on batch correction

# %% [markdown]
# Batch correction with scanorama:

# %%
# import scanorama

# # merge all the balf_samples into a single object
# balf_log = sc.concat(balf_samples.values())
# balf_log.obs_names_make_unique()

# # correct with scanorama
# balf_corrected = scanorama.correct_scanpy(adatas=list(balf_samples.values()), return_dimred=False)

# # aggregate into one object
# balf_corrected = sc.concat(balf_corrected) 
# balf_corrected.obs_names_make_unique()

# # store log(1+CPM) values in "raw" attribute
# balf_corrected.raw = balf_log

# %% [markdown]
# Batch correction using a simple linear regression:

# %%
# # merge the balf_samples
# balf_corrected = sc.concat(balf_samples.values())
# balf_corrected.obs_names_make_unique()

# # store log(1+CPM) values in "raw" attribute
# balf_corrected.raw = balf_corrected

# # do the batch correction
# sc.pp.regress_out(balf_corrected, keys = batch_var)

# %% [markdown]
# Calculate a PCA manifold on the batch-corrected counts

# %%
# get the top 2000 highly variable genes
sc.pp.highly_variable_genes(balf_corrected, n_top_genes = 2000)

# get PCA to 100 PCs
sc.tl.pca(balf_corrected, use_highly_variable = True, svd_solver='arpack', random_state = seed, 
         n_comps = 100)

# %%
# TODO: make this corrected object, the raw data, and metadata available to download somewhere
out_path = '/data3/hratch/c2c_general/'
balf_corrected.write_h5ad(out_path + 'batch_corrected_balf_covid.h5ad') # 6.7Gb

# %% [markdown]
# The final "balf_corrected" AnnData object has the following attributes:
# 1) X: batch-correct counts matrix (preferably non-negative) <br>
# 2) obs: cell metadata that includes the cell group (cluster or type), Sample ID, and Context <br>
# 3) raw: log(1+CPM) normalized AnnData object <br>
# 4) obsm['X_pca']: the cell manifold
#
# Regardless of the preprocessing pipeline used, these four pieces of information will be necessary for some parts of the Tensor-cell2cell analyses.

# %%
# corrected counts matrix
balf_corrected.to_df().T.head()
# Out:
#            AAACCTGAGGAATCGC-1  AAACCTGTCCAGAAGG-1  AAACCTGTCCAGTAGT-1  \
# LINC00115           -0.026211            3.884047           -0.026211
# NOC2L               -0.276392           -0.276392           -0.276392
# KLHL17              -0.045777           -0.045777           -0.045777
# PLEKHN1             -0.061546           -0.061546           -0.061546
# HES4                -0.444072            4.559903           -0.444072
#
#            AAACCTGTCTGGGCCA-1  AAACGGGCACGAGGTA-1  AAACGGGGTACATCCA-1  \
# LINC00115           -0.026211            4.615011           -0.026211
# NOC2L               -0.276392           -0.276392           -0.276392
# KLHL17              -0.045777           -0.045777           -0.045777
# PLEKHN1             -0.061546           -0.061546           -0.061546
# HES4                -0.444072           -0.444072           -0.444072
#
#            AAACGGGGTCTCCCTA-1  AAACGGGTCTAGAGTC-1  AAAGATGTCGTGGGAA-1  \
# LINC00115           -0.026211           -0.026211           -0.026211
# NOC2L               -0.276392           -0.276392           -0.276392
# KLHL17              -0.045777           -0.045777           -0.045777
# PLEKHN1             -0.061546           -0.061546           -0.061546
# HES4                -0.444072           -0.444072           -0.444072
#
#            AAAGCAAAGGGATACC-1  ...  TTTGGTTAGCACGCCT-1  TTTGGTTAGTGGTAAT-1  \
# LINC00115            4.423844  ...           -0.031741           -0.031741
# NOC2L               -0.276392  ...           -0.434179           -0.434179
# KLHL17              -0.045777  ...           -0.019993           -0.019993
# PLEKHN1             -0.061546  ...            0.002228            0.002228
# HES4                -0.444072  ...            0.562998            0.562998
#
#            TTTGGTTAGTTGTAGA-1-1  TTTGGTTCATACTACG-1  TTTGTCAAGATTACCC-1  \
# LINC00115             -0.031741           -0.031741           -0.031741
# NOC2L                  2.241069           -0.434179           -0.434179
# KLHL17                -0.019993           -0.019993           -0.019993
# PLEKHN1                0.002228            0.002228            0.002228
# HES4                   0.562998            0.562998            0.562998
#
#            TTTGTCAAGTGGTAAT-1  TTTGTCACAGAAGCAC-1  TTTGTCATCAACCAAC-1  \
# LINC00115           -0.031741           -0.031741           -0.031741
# NOC2L               -0.434179           -0.434179           -0.434179
# KLHL17              -0.019993           -0.019993           -0.019993
# PLEKHN1              0.002228            0.002228            0.002228
# HES4                 0.562998            0.562998            0.562998
#
#            TTTGTCATCCAAACAC-1  TTTGTCATCGCGTTTC-1
# LINC00115           -0.031741           -0.031741
# NOC2L               -0.434179           -0.434179
# KLHL17              -0.019993           -0.019993
# PLEKHN1              0.002228            0.002228
# HES4                 0.562998            6.038211
#
# [5 rows x 63102 columns]

# %%
# cell metadata
balf_corrected.obs.head()
# Out:
#                    Sample_ID       Context    cell_type  n_genes  \
# AAACCTGAGGAATCGC-1      C148  Severe_Covid  Macrophages      606
# AAACCTGTCCAGAAGG-1      C148  Severe_Covid  Macrophages     2035
# AAACCTGTCCAGTAGT-1      C148  Severe_Covid  Macrophages     1660
# AAACCTGTCTGGGCCA-1      C148  Severe_Covid  Macrophages     4965
# AAACGGGCACGAGGTA-1      C148  Severe_Covid            T     1290
#
#                     n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCTGAGGAATCGC-1                606        1342.0             60.0
# AAACCTGTCCAGAAGG-1               2034        7297.0            334.0
# AAACCTGTCCAGTAGT-1               1658        4959.0            324.0
# AAACCTGTCTGGGCCA-1               4964       31956.0           1374.0
# AAACGGGCACGAGGTA-1               1288        2892.0            119.0
#
#                     pct_counts_mt
# AAACCTGAGGAATCGC-1       4.470939
# AAACCTGTCCAGAAGG-1       4.577224
# AAACCTGTCCAGTAGT-1       6.533575
# AAACCTGTCTGGGCCA-1       4.299662
# AAACGGGCACGAGGTA-1       4.114799

# %%
# log(1+CPM) counts matrix
balf_corrected.raw.to_adata().to_df().T.head()
# Out:
#            AAACCTGAGGAATCGC-1  AAACCTGTCCAGAAGG-1  AAACCTGTCCAGTAGT-1  \
# LINC00115                 0.0            4.927562                 0.0
# NOC2L                     0.0            0.000000                 0.0
# KLHL17                    0.0            0.000000                 0.0
# PLEKHN1                   0.0            0.000000                 0.0
# HES4                      0.0            6.021334                 0.0
#
#            AAACCTGTCTGGGCCA-1  AAACGGGCACGAGGTA-1  AAACGGGGTACATCCA-1  \
# LINC00115                 0.0            5.848695                 0.0
# NOC2L                     0.0            0.000000                 0.0
# KLHL17                    0.0            0.000000                 0.0
# PLEKHN1                   0.0            0.000000                 0.0
# HES4                      0.0            0.000000                 0.0
#
#            AAACGGGGTCTCCCTA-1  AAACGGGTCTAGAGTC-1  AAAGATGTCGTGGGAA-1  \
# LINC00115                 0.0                 0.0                 0.0
# NOC2L                     0.0                 0.0                 0.0
# KLHL17                    0.0                 0.0                 0.0
# PLEKHN1                   0.0                 0.0                 0.0
# HES4                      0.0                 0.0                 0.0
#
#            AAAGCAAAGGGATACC-1  ...  TTTGGTTAGCACGCCT-1  TTTGGTTAGTGGTAAT-1  \
# LINC00115            5.607794  ...                 0.0                 0.0
# NOC2L                0.000000  ...                 0.0                 0.0
# KLHL17               0.000000  ...                 0.0                 0.0
# PLEKHN1              0.000000  ...                 0.0                 0.0
# HES4                 0.000000  ...                 0.0                 0.0
#
#            TTTGGTTAGTTGTAGA-1-1  TTTGGTTCATACTACG-1  TTTGTCAAGATTACCC-1  \
# LINC00115              0.000000                 0.0                 0.0
# NOC2L                  3.458022                 0.0                 0.0
# KLHL17                 0.000000                 0.0                 0.0
# PLEKHN1                0.000000                 0.0                 0.0
# HES4                   0.000000                 0.0                 0.0
#
#            TTTGTCAAGTGGTAAT-1  TTTGTCACAGAAGCAC-1  TTTGTCATCAACCAAC-1  \
# LINC00115                 0.0                 0.0                 0.0
# NOC2L                     0.0                 0.0                 0.0
# KLHL17                    0.0                 0.0                 0.0
# PLEKHN1                   0.0                 0.0                 0.0
# HES4                      0.0                 0.0                 0.0
#
#            TTTGTCATCCAAACAC-1  TTTGTCATCGCGTTTC-1
# LINC00115                 0.0            0.000000
# NOC2L                     0.0            0.000000
# KLHL17                    0.0            0.000000
# PLEKHN1                   0.0            0.000000
# HES4                      0.0            3.693111
#
# [5 rows x 63102 columns]

# %%
# cell manifold
pd.DataFrame(balf_corrected.obsm['X_pca'], 
            columns = ['PC' + str(i) for i in range(1, 101)], 
                      index = balf_corrected.obs.index.tolist()).head()
# Out:
#                           PC1        PC2       PC3        PC4       PC5  \
# AAACCTGAGGAATCGC-1 -12.279510 -11.569539  2.333932  -0.792567 -2.818772
# AAACCTGTCCAGAAGG-1   4.993004  -9.634439 -4.017168   6.867777 -3.659773
# AAACCTGTCCAGTAGT-1  -4.327682  -9.474691 -0.373740  -1.574611  1.026707
# AAACCTGTCTGGGCCA-1  21.996510   2.566066 -3.944390 -13.916259  7.445151
# AAACGGGCACGAGGTA-1 -18.817038   4.994419 -9.384811  -6.844615 -3.056098
#
#                          PC6       PC7       PC8       PC9      PC10  ...  \
# AAACCTGAGGAATCGC-1  2.152842  1.414543 -2.819450 -0.843046 -0.359107  ...
# AAACCTGTCCAGAAGG-1  2.181219  2.381791  5.002475  4.327793 -2.199009  ...
# AAACCTGTCCAGTAGT-1  0.264881 -0.642445  2.645939  0.768080  1.401344  ...
# AAACCTGTCTGGGCCA-1  3.117134  1.296663  2.814822 -1.560574 -0.914551  ...
# AAACGGGCACGAGGTA-1  2.774960 -5.017649  0.400225  0.813033  0.663741  ...
#
#                         PC91      PC92      PC93      PC94      PC95  \
# AAACCTGAGGAATCGC-1  0.636127 -0.555673 -1.174195  0.382731 -1.154741
# AAACCTGTCCAGAAGG-1  1.056841 -0.549429 -1.792231 -1.502628  3.608827
# AAACCTGTCCAGTAGT-1 -1.219072 -1.509040  0.535264 -2.544001 -2.009928
# AAACCTGTCTGGGCCA-1 -1.616594 -0.872157 -2.061459 -0.744164 -1.183877
# AAACGGGCACGAGGTA-1  1.176409  0.047743 -0.064789  2.626716  0.151935
#
#                         PC96      PC97      PC98      PC99     PC100
# AAACCTGAGGAATCGC-1  1.880821 -2.175864  0.964448  2.638466  2.882710
# AAACCTGTCCAGAAGG-1  0.246818  2.478500 -0.412751  2.093467 -2.841379
# AAACCTGTCCAGTAGT-1  0.517890 -0.087034  0.123314  0.314210 -3.137026
# AAACCTGTCTGGGCCA-1 -4.804202 -1.866552  2.740477  1.292481 -1.160910
# AAACGGGCACGAGGTA-1  0.872773 -1.538529 -0.425076  1.315260 -0.842731
#
# [5 rows x 100 columns]

# %%
# from typing import Dict
# def split_adata(adata, sample_col = 'Sample_ID'):
#     """Split an AnnData object with corrected counts into its respective balf_samples.

#     Parameters
#     ----------
#     adata : AnnData
#         merged AnnData object across balf_samples (see sc.concat)
#     sample_col : str, optional
#         the metadata (adata.obs) column specifying the balf_samples, by default 'Sample_ID'

#     Returns
#     -------
#     balf_samples : Dict[str, AnnData]
#         the set of AnnData objects corresponding to each sample
#     """
    
#     balf_samples = {sample: adata[adata.obs[adata.obs[sample_col] == sample].index] for sample in adata.obs[sample_col].unique()}
#     return balf_samples


# balf_corrected_split = split_adata(adata=balf_corrected)
